# %%
import pandas as pd

# %%
pd.read_csv("1617PerGameBasic.csv")
# Out:
#       Rk                           Player Pos  Age   Tm   G  GS    MP   FG  \
# 0      1           Alex Abrines\abrinal01  SG   23  OKC  68   6  15.5  2.0
# 1      2               Quincy Acy\acyqu01  PF   26  TOT  38   1  14.7  1.8
# 2      2               Quincy Acy\acyqu01  PF   26  DAL   6   0   8.0  0.8
# 3      2               Quincy Acy\acyqu01  PF   26  BRK  32   1  15.9  2.0
# 4      3           Steven Adams\adamsst01   C   23  OKC  80  80  29.9  4.7
# 5      4          Arron Afflalo\afflaar01  SG   31  SAC  61  45  25.9  3.0
# 6      5          Alexis Ajinca\ajincal01   C   28  NOP  39  15  15.0  2.3
# 7      6           Cole Aldrich\aldrico01   C   28  MIN  62   0   8.6  0.7
# 8      7      LaMarcus Aldridge\aldrila01  PF   31  SAS  72  72  32.4  6.9
# 9      8            Lavoy Allen\allenla01  PF   27  IND  61   5  14.3  1.3
# 10     9             Tony Allen\allento01  SG   35  MEM  71  66  27.0  3.9
# ...
