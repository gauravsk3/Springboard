# %%
import pandas as pd

# %%
import http.client, urllib.request, urllib.parse, urllib.error, base64

headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': '9f2f1124447c42978f6ba81d55e5a6bf',
}

params = urllib.parse.urlencode({
})

try:
    conn = http.client.HTTPSConnection('api.fantasydata.net')
    conn.request("GET", "/v3/nba/projections/JSON/PlayerGameProjectionStatsByDate/2017-OCT-17?%s" % params, "{body}", headers)
    response = conn.getresponse()
    data = response.read()
    print(data)
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))
# Out:
# b'[{"StatID":396063,"TeamID":9,"PlayerID":20000560,"SeasonType":1,"Season":2018,"Name":"Marcus Smart","Team":"BOS","Position":"PG","Started":0,"FanDuelSalary":5973,"DraftKingsSalary":5409,"FantasyDataSalary":5409,"YahooSalary":20,"InjuryStatus":"Scrambled","InjuryBodyPart":"Scrambled","InjuryStartDate":null,"InjuryNotes":"Scrambled","FanDuelPosition":"PG","DraftKingsPosition":"PG\\/SG","YahooPosition":"SG","OpponentRank":24,"OpponentPositionRank":25,"GlobalTeamID":20000009,"FantasyDraftSalary":10706,"FantasyDraftPosition":"Scrambled","GameID":11148,"OpponentID":12,"Opponent":"CLE","Day":"2017-10-17T00:00:00","DateTime":"2017-10-17T20:00:00","HomeOrAway":"AWAY","IsGameOver":true,"GlobalGameID":20011148,"GlobalOpponentID":20000012,"Updated":"2017-11-07T10:35:39","Games":1,"FantasyPoints":25.4,"Minutes":30,"Seconds":38,"FieldGoalsMade":3.4,"FieldGoalsAttempted":9.3,"FieldGoalsPercentage":42.3,"EffectiveFieldGoalsPercentage":56.4,"TwoPointersMade":1.8,"TwoPointersAttempted":4.6,"TwoPoint
# ...

# %%
frame = pd.read_json(data)

# %%
pd.set_option('display.max_columns',84)
frame
# Out:
#     Assists  AssistsPercentage  BlockedShots  BlocksPercentage  \
# 0       4.9                NaN           0.5               NaN
# 1       6.5                NaN           0.4               NaN
# 2       5.5                NaN           0.9               NaN
# 3       0.3                NaN           0.3               NaN
# 4       5.8                NaN           0.2               NaN
# 5       4.2                NaN           0.3               NaN
# 6       0.0                NaN           0.0               NaN
# 7       2.3                NaN           0.2               NaN
# 8       1.5                NaN           0.3               NaN
# 9       0.3                NaN           0.1               NaN
# 10      0.3                NaN           0.1               NaN
# 11      1.5                NaN           0.5               NaN
# 12      0.2                NaN           0.1               NaN
# 13      0.4                NaN           0.1               NaN
# ...
